# %%
import cv2
import numpy as np
from ultralytics import YOLO
import threading
import time

class CCTVDetectionSystem:
    def __init__(self, video_source=0, resize_width=640, resize_height=480):
        self.video_source = video_source
        self.cap = None
        self.model = None
        self.resize_width = resize_width
        self.resize_height = resize_height
        
        self.setup_video()
        self.load_model()
        
        self.running = False
        self.people_frame = None
        self.zebra_frame = None
        self.road_frame = None
        self.violation_frame = None
        self.original_frame = None
        
    
    def setup_video(self):
        self.cap = cv2.VideoCapture(self.video_source)
        if not self.cap.isOpened():
            raise ValueError(f"Error: Could not open video source {self.video_source}")
        self.cap.set(cv2.CAP_PROP_BUFFERSIZE, 1)
    
    def load_model(self):
        try:
            self.model = YOLO('yolov8n.pt')
        except Exception as e:
            print(f"Error loading YOLO model: {e}")
            print("Please install ultralytics: pip install ultralytics")
    
    def detect_people(self, frame, results=None):
        if self.model is None:
            return frame
        try:
            annotated_frame = frame.copy()
            if results is None:
                results = self.model(frame, classes=[0])
            for result in results:
                boxes = result.boxes
                if boxes is not None:
                    for box in boxes:
                        x1, y1, x2, y2 = box.xyxy[0].cpu().numpy().astype(int)
                        confidence = box.conf[0].cpu().numpy()
                        if confidence > 0.5:
                            cv2.rectangle(annotated_frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
                            label = f'Person: {confidence:.2f}'
                            cv2.putText(annotated_frame, label, (x1, y1-10), 
                                       cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)
            return annotated_frame
        except Exception as e:
            print(f"Error in people detection: {e}")
            return frame
    
    def detect_zebra_crossing(self, frame):
        try:
            result_frame = frame.copy()
            height, width = frame.shape[:2]
            
            zebra_polygon = np.array([
                [int(width * 0.825), int(height * 0.460)],
                [int(width * 0.489), int(height * 0.404)],
                [int(width * 0.567), int(height * 0.365)],
                [int(width * 0.864), int(height * 0.404)]
            ], np.int32)
            
            overlay = result_frame.copy()
            cv2.fillPoly(overlay, [zebra_polygon], (0, 255, 255))
            result_frame = cv2.addWeighted(result_frame, 0.7, overlay, 0.3, 0)
            cv2.polylines(result_frame, [zebra_polygon], True, (0, 255, 255), 3)
            
            area = cv2.contourArea(zebra_polygon)
            cv2.putText(result_frame, f'Area: {int(area)} pixels', 
                       (zebra_polygon[0][0], zebra_polygon[3][1] + 20), 
                       cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 255), 2)
            
            for point in zebra_polygon:
                cv2.circle(result_frame, tuple(point), 5, (255, 0, 0), -1)
            
            cv2.putText(result_frame, 'STATUS: ZEBRA CROSSING ACTIVE', 
                       (10, height - 40), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 0), 2)
            cv2.putText(result_frame, 'Mode: Predefined Area Detection', 
                       (10, height - 20), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 1)
            
            return result_frame
        except Exception as e:
            print(f"Error in zebra crossing detection: {e}")
            return frame
    
    def detect_road_area(self, frame):
        try:
            result_frame = frame.copy()
            height, width = frame.shape[:2]
            
            road_polygon = np.array([
                [int(width * 0.745), int(height * 0.275)],
                [int(width * 0.909), int(height * 0.308)],
                [int(width * 0.514), int(height * 0.990)],
                [int(width * 0.000), int(height * 0.992)],
                [int(width * 0.003), int(height * 0.660)]
            ], np.int32)
            
            overlay = result_frame.copy()
            cv2.fillPoly(overlay, [road_polygon], (255, 150, 50))
            result_frame = cv2.addWeighted(result_frame, 0.6, overlay, 0.4, 0)
            cv2.polylines(result_frame, [road_polygon], True, (255, 100, 0), 3)
            
            for i, point in enumerate(road_polygon):
                cv2.circle(result_frame, tuple(point), 8, (0, 0, 255), -1)
                cv2.putText(result_frame, str(i+1), (point[0]+10, point[1]-10), 
                           cv2.FONT_HERSHEY_SIMPLEX, 0.7, (255, 255, 255), 2)
            
            cv2.putText(result_frame, 'ROAD AREA DETECTION', 
                       (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (255, 100, 0), 2)
            cv2.putText(result_frame, 'PREDEFINED ROAD ZONE', 
                       (10, 55), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 150, 50), 2)
            
            area = cv2.contourArea(road_polygon)
            cv2.putText(result_frame, f'Road Area: {int(area)} pixels', 
                       (10, 80), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 150, 50), 2)
            
            frame_area = width * height
            coverage_percent = (area / frame_area) * 100
            cv2.putText(result_frame, f'Coverage: {coverage_percent:.1f}% of frame', 
                       (10, 105), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 150, 50), 2)
            
            cv2.putText(result_frame, 'Road Coordinates (% of frame):', 
                       (10, height - 120), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 1)
            coord_text = [
                "P1: (74.5%, 27.5%)", "P2: (90.9%, 30.8%)", "P3: (51.4%, 99.0%)",
                "P4: (0.0%, 99.2%)", "P5: (0.3%, 66.0%)"
            ]
            for i, text in enumerate(coord_text):
                cv2.putText(result_frame, text, (10, height - 95 + i*15), 
                           cv2.FONT_HERSHEY_SIMPLEX, 0.4, (255, 255, 255), 1)
            
            cv2.putText(result_frame, 'STATUS: ROAD AREA ACTIVE', 
                       (10, height - 20), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 0), 2)
            
            return result_frame
        except Exception as e:
            print(f"Error in road area detection: {e}")
            return frame
    
    def detect_violations(self, frame, results=None):
        try:
            # Start with clean frame copy - NO overlays
            result_frame = frame.copy()
            height, width = frame.shape[:2]
            
            zebra_polygon = np.array([
                [int(width * 0.825), int(height * 0.460)],
                [int(width * 0.489), int(height * 0.404)],
                [int(width * 0.567), int(height * 0.365)],
                [int(width * 0.864), int(height * 0.404)]
            ], np.int32)
            
            road_polygon = np.array([
                [int(width * 0.745), int(height * 0.275)],
                [int(width * 0.909), int(height * 0.308)],
                [int(width * 0.514), int(height * 0.990)],
                [int(width * 0.000), int(height * 0.992)],
                [int(width * 0.003), int(height * 0.660)]
            ], np.int32)
            
            if results is None:
                results = self.model(frame, classes=[0])
            
            violation_count = 0
            
            for result in results:
                boxes = result.boxes
                if boxes is not None:
                    for box in boxes:
                        x1, y1, x2, y2 = box.xyxy[0].cpu().numpy().astype(int)
                        confidence = box.conf[0].cpu().numpy()
                        
                        if confidence > 0.2:
                            # Use bottom center of the bounding box
                            center_x = float((x1 + x2) / 2.0)
                            center_y = float(y2)  # Bottom of the box
                            
                            in_road = cv2.pointPolygonTest(road_polygon, (center_x, center_y), False) >= 0
                            in_zebra = cv2.pointPolygonTest(zebra_polygon, (center_x, center_y), False) >= 0
                            
                            # Debug output
                            print(f"Person at bottom center ({center_x}, {center_y}) - in_road: {in_road}, in_zebra: {in_zebra}")
                            
                            # VIOLATION: Person is in road BUT NOT in zebra crossing
                            if in_road and not in_zebra:
                                violation_count += 1
                                cv2.rectangle(result_frame, (x1, y1), (x2, y2), (0, 0, 255), 3)
                                cv2.putText(result_frame, f'VIOLATION: {confidence:.2f}', (x1, y1-10), 
                                           cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 0, 255), 2)
                                cv2.circle(result_frame, (int(center_x), int(center_y)), 5, (0, 0, 255), -1)
            
            # Display violation count and info - clean display without zone overlays
            cv2.putText(result_frame, f'VIOLATIONS: {violation_count}', (10, 30), 
                       cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 0, 255), 2)
            cv2.putText(result_frame, 'VIOLATION DETECTION - CLEAN VIEW', (10, 55), 
                       cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 255, 255), 2)
            cv2.putText(result_frame, 'Red boxes: People in road but NOT in zebra crossing', (10, 80), 
                       cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 1)
            
            # NO zone overlays - just the clean frame with violation markers
            
            return result_frame
            
        except Exception as e:
            print(f"Error in violation detection: {e}")
            return frame
    
    def process_frame(self, frame):
        resized_frame = cv2.resize(frame, (self.resize_width, self.resize_height))
        self.original_frame = resized_frame.copy()
        results = self.model(resized_frame, classes=[0]) if self.model else None
        self.people_frame = self.detect_people(resized_frame, results)
        self.zebra_frame = self.detect_zebra_crossing(resized_frame)
        self.road_frame = self.detect_road_area(resized_frame)
        self.violation_frame = self.detect_violations(resized_frame, results)
    
    def display_windows(self):
        cv2.namedWindow('People Detection') 
        cv2.namedWindow('Zebra Crossing Detection')
        cv2.namedWindow('Road Area Detection')
        cv2.namedWindow('Violation Detection')
        
        while self.running:
            if self.people_frame is not None:
                cv2.imshow('People Detection', self.people_frame)
                
            if self.zebra_frame is not None:
                cv2.imshow('Zebra Crossing Detection', self.zebra_frame)
            
            if self.road_frame is not None:
                cv2.imshow('Road Area Detection', self.road_frame)
            
            if self.violation_frame is not None:
                cv2.imshow('Violation Detection', self.violation_frame)
            
            key = cv2.waitKey(1) & 0xFF
            if key == ord('q'):
                self.running = False
                break
                
        cv2.destroyAllWindows()
    
    def run(self):
        print("Starting CCTV Detection System with Clean Violation Detection...")
        print("="*70)
        print("CONTROLS:")
        print("- Press 'q' to quit")
        print("="*70)
        print("\nDETECTION WINDOWS:")
        print("1. People Detection - Green boxes around detected people")
        print("2. Zebra Crossing - Cyan area marking the crossing zone")
        print("3. Road Area - Orange area marking the road surface")
        print("4. Violation Detection - CLEAN VIEW with RED boxes for violations only")
        print("   (No zone overlays - just violations highlighted)")
        print("="*70 + "\n")
        
        self.running = True
        display_thread = threading.Thread(target=self.display_windows)
        display_thread.daemon = True
        display_thread.start()
        
        start_time = time.time()
        frame_count = 0
        
        while self.running:
            ret, frame = self.cap.read()
            if not ret:
                print("Error reading frame or end of video")
                break
            self.process_frame(frame)
            frame_count += 1
            if time.time() - start_time > 1:
                fps = frame_count / (time.time() - start_time)
                print(f"FPS: {fps:.2f}")
                frame_count = 0
                start_time = time.time()
            time.sleep(0.03)
        
        self.cap.release()
        cv2.destroyAllWindows()
        print("CCTV Detection System stopped")

def main():
    video_source = "Video_2025_08_07-1.mp4"  # Replace with full path if needed
    resize_width = 640
    resize_height = 480
    try:
        detector = CCTVDetectionSystem(video_source, resize_width, resize_height)
        detector.run()
    except KeyboardInterrupt:
        print("\nInterrupted by user")
    except Exception as e:
        print(f"Error: {e}")

if __name__ == "__main__":
    main()
# Out:
# Starting CCTV Detection System with Clean Violation Detection...
# ======================================================================
# CONTROLS:
# - Press 'q' to quit
# ======================================================================
#
# DETECTION WINDOWS:
# 1. People Detection - Green boxes around detected people
# 2. Zebra Crossing - Cyan area marking the crossing zone
# 3. Road Area - Orange area marking the road surface
# 4. Violation Detection - CLEAN VIEW with RED boxes for violations only
#    (No zone overlays - just violations highlighted)
# ======================================================================
#
#
# 0: 480x640 10 persons, 215.6ms
# Speed: 9.2ms preprocess, 215.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person at bottom center (23.0, 281.0) - in_road: False, in_zebra: False
# Person at bottom center (582.5, 309.0) - in_road: False, in_zebra: False
# Person at bottom center (538.0, 447.0) - in_road: False, in_zebra: False
# Person at bottom center (581.5, 448.0) - in_road: False, in_zebra: False
# Person at bottom center (460.5, 444.0) - in_road: False, in_zebra: False
# Person at bottom center (323.5, 169.0) - in_road: False, in_zebra: False
# Person at bottom center (6.5, 279.0) - in_road: False, in_zebra: False
# Person at bottom center (489.5, 445.0) - in_road: False, in_zebra: False
# Person at bottom center (308.0, 173.0) - in_road: False, in_zebra: False
# Person at bottom center (583.5, 188.0) - in_road: False, in_zebra: False
#
# 0: 480x640 9 persons, 255.3ms
# Speed: 4.0ms preprocess, 255.3ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
# Person at bottom center (23.0, 281.0) - in_road: False, in_zebra: False
# Person at bottom center (583.0, 308.0) - in_road: False, in_zebra: False
# Person at bottom center (581.0, 447.0) - in_road: False, in_zebra: False
# Person at bottom center (538.0, 447.0) - in_road: False, in_zebra: False
# Person at bottom center (461.0, 444.0) - in_road: False, in_zebra: False
# Person at bottom center (323.5, 169.0) - in_road: False, in_zebra: False
# Person at bottom center (488.0, 445.0) - in_road: False, in_zebra: False
# Person at bottom center (6.0, 279.0) - in_road: False, in_zebra: False
# Person at bottom center (583.5, 188.0) - in_road: False, in_zebra: False
#
# 0: 480x640 8 persons, 207.8ms
# Speed: 7.3ms preprocess, 207.8ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
# Person at bottom center (583.5, 309.0) - in_road: False, in_zebra: False
# Person at bottom center (22.5, 281.0) - in_road: False, in_zebra: False
# Person at bottom center (581.0, 447.0) - in_road: False, in_zebra: False
# Person at bottom center (461.5, 443.0) - in_road: False, in_zebra: False
# Person at bottom center (537.5, 447.0) - in_road: False, in_zebra: False
# Person at bottom center (323.5, 170.0) - in_road: False, in_zebra: False
# Person at bottom center (6.0, 279.0) - in_road: False, in_zebra: False
# Person at bottom center (487.5, 445.0) - in_road: False, in_zebra: False
# FPS: 2.88
#
# 0: 480x640 10 persons, 513.3ms
# Speed: 8.7ms preprocess, 513.3ms inference, 3.8ms postprocess per image at shape (1, 3, 480, 640)
# Person at bottom center (583.5, 307.0) - in_road: False, in_zebra: False
# Person at bottom center (22.5, 281.0) - in_road: False, in_zebra: False
# Person at bottom center (581.0, 447.0) - in_road: False, in_zebra: False
# Person at bottom center (460.5, 444.0) - in_road: False, in_zebra: False
# Person at bottom center (537.5, 446.0) - in_road: False, in_zebra: False
# Person at bottom center (323.5, 170.0) - in_road: False, in_zebra: False
# Person at bottom center (487.5, 445.0) - in_road: False, in_zebra: False
# Person at bottom center (6.0, 280.0) - in_road: False, in_zebra: False
# Person at bottom center (308.5, 173.0) - in_road: False, in_zebra: False
# Person at bottom center (583.5, 193.0) - in_road: False, in_zebra: False
#
# 0: 480x640 9 persons, 223.7ms
# Speed: 9.1ms preprocess, 223.7ms inference, 6.2ms postprocess per image at shape (1, 3, 480, 640)
# Person at bottom center (583.5, 304.0) - in_road: False, in_zebra: False
# Person at bottom center (22.5, 281.0) - in_road: False, in_zebra: False
# Person at bottom center (581.0, 447.0) - in_road: False, in_zebra: False
# Person at bottom center (460.5, 444.0) - in_road: False, in_zebra: False
# Person at bottom center (537.0, 446.0) - in_road: False, in_zebra: False
# Person at bottom center (324.0, 170.0) - in_road: False, in_zebra: False
# Person at bottom center (489.0, 446.0) - in_road: False, in_zebra: False
# Person at bottom center (6.5, 278.0) - in_road: False, in_zebra: False
# Person at bottom center (309.0, 173.0) - in_road: False, in_zebra: False
#
# 0: 480x640 9 persons, 337.3ms
# Speed: 4.7ms preprocess, 337.3ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
# Person at bottom center (584.5, 304.0) - in_road: False, in_zebra: False
# Person at bottom center (23.0, 281.0) - in_road: False, in_zebra: False
# Person at bottom center (581.0, 446.0) - in_road: False, in_zebra: False
# Person at bottom center (460.5, 444.0) - in_road: False, in_zebra: False
# Person at bottom center (534.5, 446.0) - in_road: False, in_zebra: False
# Person at bottom center (324.0, 170.0) - in_road: False, in_zebra: False
# Person at bottom center (489.0, 447.0) - in_road: False, in_zebra: False
# Person at bottom center (6.5, 277.0) - in_road: False, in_zebra: False
# Person at bottom center (309.5, 173.0) - in_road: False, in_zebra: False
# FPS: 2.25
#
# 0: 480x640 9 persons, 199.5ms
# Speed: 3.7ms preprocess, 199.5ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
# Person at bottom center (585.0, 300.0) - in_road: False, in_zebra: False
# Person at bottom center (23.0, 281.0) - in_road: False, in_zebra: False
# Person at bottom center (584.0, 447.0) - in_road: False, in_zebra: False
# Person at bottom center (461.0, 443.0) - in_road: False, in_zebra: False
# Person at bottom center (536.0, 446.0) - in_road: False, in_zebra: False
# Person at bottom center (323.5, 170.0) - in_road: False, in_zebra: False
# Person at bottom center (487.5, 446.0) - in_road: False, in_zebra: False
# Person at bottom center (6.0, 277.0) - in_road: False, in_zebra: False
# Person at bottom center (309.5, 173.0) - in_road: False, in_zebra: False
#
# 0: 480x640 9 persons, 199.9ms
# Speed: 6.1ms preprocess, 199.9ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
# Person at bottom center (585.0, 298.0) - in_road: False, in_zebra: False
# Person at bottom center (22.5, 281.0) - in_road: False, in_zebra: False
# Person at bottom center (582.5, 447.0) - in_road: False, in_zebra: False
# Person at bottom center (461.0, 443.0) - in_road: False, in_zebra: False
# Person at bottom center (323.0, 170.0) - in_road: False, in_zebra: False
# Person at bottom center (535.5, 446.0) - in_road: False, in_zebra: False
# Person at bottom center (486.5, 447.0) - in_road: False, in_zebra: False
# Person at bottom center (6.0, 279.0) - in_road: False, in_zebra: False
# Person at bottom center (309.0, 173.0) - in_road: False, in_zebra: False
#
# 0: 480x640 9 persons, 220.2ms
# Speed: 5.7ms preprocess, 220.2ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
# Person at bottom center (585.0, 298.0) - in_road: False, in_zebra: False
# Person at bottom center (22.5, 281.0) - in_road: False, in_zebra: False
# Person at bottom center (583.5, 446.0) - in_road: False, in_zebra: False
# Person at bottom center (460.5, 443.0) - in_road: False, in_zebra: False
# Person at bottom center (535.5, 446.0) - in_road: False, in_zebra: False
# Person at bottom center (323.0, 170.0) - in_road: False, in_zebra: False
# Person at bottom center (487.5, 447.0) - in_road: False, in_zebra: False
# Person at bottom center (6.0, 280.0) - in_road: False, in_zebra: False
# Person at bottom center (308.5, 173.0) - in_road: False, in_zebra: False
#
# 0: 480x640 8 persons, 231.5ms
# Speed: 5.1ms preprocess, 231.5ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# Person at bottom center (585.0, 298.0) - in_road: False, in_zebra: False
# Person at bottom center (22.5, 281.0) - in_road: False, in_zebra: False
# Person at bottom center (583.5, 446.0) - in_road: False, in_zebra: False
# Person at bottom center (460.0, 444.0) - in_road: False, in_zebra: False
# Person at bottom center (535.5, 446.0) - in_road: False, in_zebra: False
# Person at bottom center (488.5, 447.0) - in_road: False, in_zebra: False
# Person at bottom center (323.0, 170.0) - in_road: False, in_zebra: False
# Person at bottom center (6.0, 280.0) - in_road: False, in_zebra: False
# FPS: 3.42
#
# 0: 480x640 9 persons, 203.7ms
# Speed: 6.2ms preprocess, 203.7ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
# Person at bottom center (585.0, 299.0) - in_road: False, in_zebra: False
# Person at bottom center (22.5, 281.0) - in_road: False, in_zebra: False
# Person at bottom center (583.5, 446.0) - in_road: False, in_zebra: False
# Person at bottom center (460.0, 443.0) - in_road: False, in_zebra: False
# Person at bottom center (535.5, 446.0) - in_road: False, in_zebra: False
# Person at bottom center (488.5, 447.0) - in_road: False, in_zebra: False
# Person at bottom center (323.5, 170.0) - in_road: False, in_zebra: False
# Person at bottom center (7.5, 279.0) - in_road: False, in_zebra: False
# Person at bottom center (309.5, 173.0) - in_road: False, in_zebra: False
#
# 0: 480x640 10 persons, 346.7ms
# Speed: 3.7ms preprocess, 346.7ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
# Person at bottom center (585.0, 298.0) - in_road: False, in_zebra: False
# Person at bottom center (22.5, 281.0) - in_road: False, in_zebra: False
# Person at bottom center (581.5, 446.0) - in_road: False, in_zebra: False
# Person at bottom center (460.5, 443.0) - in_road: False, in_zebra: False
# Person at bottom center (534.5, 446.0) - in_road: False, in_zebra: False
# Person at bottom center (489.0, 446.0) - in_road: False, in_zebra: False
# Person at bottom center (323.5, 170.0) - in_road: False, in_zebra: False
# Person at bottom center (308.5, 173.0) - in_road: False, in_zebra: False
# Person at bottom center (7.5, 279.0) - in_road: False, in_zebra: False
# Person at bottom center (582.0, 194.0) - in_road: False, in_zebra: False
#
# 0: 480x640 8 persons, 253.7ms
# Speed: 3.3ms preprocess, 253.7ms inference, 5.6ms postprocess per image at shape (1, 3, 480, 640)
# Person at bottom center (586.0, 298.0) - in_road: False, in_zebra: False
# Person at bottom center (22.5, 281.0) - in_road: False, in_zebra: False
# Person at bottom center (582.0, 447.0) - in_road: False, in_zebra: False
# Person at bottom center (460.0, 444.0) - in_road: False, in_zebra: False
# Person at bottom center (534.5, 446.0) - in_road: False, in_zebra: False
# Person at bottom center (324.0, 170.0) - in_road: False, in_zebra: False
# Person at bottom center (490.0, 446.0) - in_road: False, in_zebra: False
# Person at bottom center (309.0, 173.0) - in_road: False, in_zebra: False
# FPS: 2.84
#
# 0: 480x640 8 persons, 274.2ms
# Speed: 7.9ms preprocess, 274.2ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
# Person at bottom center (586.0, 298.0) - in_road: False, in_zebra: False
# Person at bottom center (22.5, 281.0) - in_road: False, in_zebra: False
# Person at bottom center (581.5, 447.0) - in_road: False, in_zebra: False
# Person at bottom center (459.0, 444.0) - in_road: False, in_zebra: False
# Person at bottom center (534.0, 446.0) - in_road: False, in_zebra: False
# Person at bottom center (324.0, 170.0) - in_road: False, in_zebra: False
# Person at bottom center (491.0, 445.0) - in_road: False, in_zebra: False
# Person at bottom center (309.0, 173.0) - in_road: False, in_zebra: False
#
# 0: 480x640 10 persons, 292.2ms
# Speed: 3.7ms preprocess, 292.2ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
# Person at bottom center (587.0, 297.0) - in_road: False, in_zebra: False
# Person at bottom center (23.0, 281.0) - in_road: False, in_zebra: False
# Person at bottom center (581.5, 447.0) - in_road: False, in_zebra: False
# Person at bottom center (460.0, 444.0) - in_road: False, in_zebra: False
# Person at bottom center (534.5, 446.0) - in_road: False, in_zebra: False
# Person at bottom center (491.0, 446.0) - in_road: False, in_zebra: False
# Person at bottom center (323.5, 170.0) - in_road: False, in_zebra: False
# Person at bottom center (584.0, 192.0) - in_road: False, in_zebra: False
# Person at bottom center (309.0, 172.0) - in_road: False, in_zebra: False
# Person at bottom center (580.0, 195.0) - in_road: False, in_zebra: False
#
# 0: 480x640 9 persons, 247.2ms
# Speed: 4.9ms preprocess, 247.2ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
# Person at bottom center (587.5, 297.0) - in_road: False, in_zebra: False
# Person at bottom center (23.0, 281.0) - in_road: False, in_zebra: False
# Person at bottom center (581.0, 447.0) - in_road: False, in_zebra: False
# Person at bottom center (460.0, 444.0) - in_road: False, in_zebra: False
# Person at bottom center (490.5, 446.0) - in_road: False, in_zebra: False
# Person at bottom center (534.5, 446.0) - in_road: False, in_zebra: False
# Person at bottom center (324.0, 170.0) - in_road: False, in_zebra: False
# Person at bottom center (309.0, 172.0) - in_road: False, in_zebra: False
# Person at bottom center (583.0, 191.0) - in_road: False, in_zebra: False
# FPS: 2.80
#
# 0: 480x640 9 persons, 373.4ms
# Speed: 9.0ms preprocess, 373.4ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# Person at bottom center (588.0, 297.0) - in_road: False, in_zebra: False
# Person at bottom center (24.0, 281.0) - in_road: False, in_zebra: False
# Person at bottom center (581.5, 447.0) - in_road: False, in_zebra: False
# Person at bottom center (491.5, 446.0) - in_road: False, in_zebra: False
# Person at bottom center (459.0, 444.0) - in_road: False, in_zebra: False
# Person at bottom center (324.0, 170.0) - in_road: False, in_zebra: False
# Person at bottom center (535.0, 446.0) - in_road: False, in_zebra: False
# Person at bottom center (309.0, 172.0) - in_road: False, in_zebra: False
# Person at bottom center (583.5, 189.0) - in_road: False, in_zebra: False
#
# 0: 480x640 10 persons, 331.0ms
# Speed: 12.2ms preprocess, 331.0ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
# Person at bottom center (589.0, 294.0) - in_road: False, in_zebra: False
# Person at bottom center (24.0, 281.0) - in_road: False, in_zebra: False
# Person at bottom center (580.5, 447.0) - in_road: False, in_zebra: False
# Person at bottom center (536.0, 446.0) - in_road: False, in_zebra: False
# Person at bottom center (491.0, 445.0) - in_road: False, in_zebra: False
# Person at bottom center (457.5, 444.0) - in_road: False, in_zebra: False
# Person at bottom center (323.5, 170.0) - in_road: False, in_zebra: False
# Person at bottom center (308.0, 172.0) - in_road: False, in_zebra: False
# Person at bottom center (584.0, 189.0) - in_road: False, in_zebra: False
# Person at bottom center (6.5, 280.0) - in_road: False, in_zebra: False
#
# 0: 480x640 10 persons, 416.8ms
# Speed: 21.0ms preprocess, 416.8ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
# Person at bottom center (590.5, 293.0) - in_road: False, in_zebra: False
# Person at bottom center (24.0, 281.0) - in_road: False, in_zebra: False
# Person at bottom center (580.5, 447.0) - in_road: False, in_zebra: False
# Person at bottom center (537.0, 446.0) - in_road: False, in_zebra: False
# Person at bottom center (490.5, 445.0) - in_road: False, in_zebra: False
# Person at bottom center (458.5, 444.0) - in_road: False, in_zebra: False
# Person at bottom center (324.0, 170.0) - in_road: False, in_zebra: False
# Person at bottom center (584.0, 189.0) - in_road: False, in_zebra: False
# Person at bottom center (309.0, 172.0) - in_road: False, in_zebra: False
# Person at bottom center (6.5, 280.0) - in_road: False, in_zebra: False
# FPS: 2.10
#
# 0: 480x640 11 persons, 323.0ms
# Speed: 9.4ms preprocess, 323.0ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
# Person at bottom center (591.0, 291.0) - in_road: False, in_zebra: False
# Person at bottom center (24.0, 281.0) - in_road: False, in_zebra: False
# Person at bottom center (581.0, 446.0) - in_road: False, in_zebra: False
# Person at bottom center (538.0, 446.0) - in_road: False, in_zebra: False
# Person at bottom center (489.0, 445.0) - in_road: False, in_zebra: False
# Person at bottom center (456.5, 445.0) - in_road: False, in_zebra: False
# Person at bottom center (323.5, 170.0) - in_road: False, in_zebra: False
# Person at bottom center (7.0, 280.0) - in_road: False, in_zebra: False
# Person at bottom center (584.0, 190.0) - in_road: False, in_zebra: False
# Person at bottom center (309.5, 172.0) - in_road: False, in_zebra: False
# Person at bottom center (579.5, 196.0) - in_road: False, in_zebra: False
#
# 0: 480x640 13 persons, 195.4ms
# Speed: 4.0ms preprocess, 195.4ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
# Person at bottom center (591.5, 291.0) - in_road: False, in_zebra: False
# Person at bottom center (24.0, 281.0) - in_road: False, in_zebra: False
# Person at bottom center (580.5, 446.0) - in_road: False, in_zebra: False
# Person at bottom center (537.5, 446.0) - in_road: False, in_zebra: False
# Person at bottom center (489.5, 445.0) - in_road: False, in_zebra: False
# Person at bottom center (456.5, 444.0) - in_road: False, in_zebra: False
# Person at bottom center (324.0, 170.0) - in_road: False, in_zebra: False
# Person at bottom center (578.5, 196.0) - in_road: False, in_zebra: False
# Person at bottom center (7.0, 280.0) - in_road: False, in_zebra: False
# Person at bottom center (582.0, 190.0) - in_road: False, in_zebra: False
# Person at bottom center (308.5, 172.0) - in_road: False, in_zebra: False
# Person at bottom center (585.5, 191.0) - in_road: False, in_zebra: False
# Person at bottom center (301.5, 171.0) - in_road: False, in_zebra: False
#
# 0: 480x640 12 persons, 239.9ms
# Speed: 7.0ms preprocess, 239.9ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
# Person at bottom center (591.5, 290.0) - in_road: False, in_zebra: False
# Person at bottom center (24.0, 281.0) - in_road: False, in_zebra: False
# Person at bottom center (580.0, 447.0) - in_road: False, in_zebra: False
# Person at bottom center (538.0, 446.0) - in_road: False, in_zebra: False
# Person at bottom center (456.0, 444.0) - in_road: False, in_zebra: False
# Person at bottom center (490.0, 445.0) - in_road: False, in_zebra: False
# Person at bottom center (324.0, 170.0) - in_road: False, in_zebra: False
# Person at bottom center (578.5, 197.0) - in_road: False, in_zebra: False
# Person at bottom center (583.5, 190.0) - in_road: False, in_zebra: False
# Person at bottom center (7.0, 280.0) - in_road: False, in_zebra: False
# Person at bottom center (309.5, 172.0) - in_road: False, in_zebra: False
# Person at bottom center (575.5, 197.0) - in_road: False, in_zebra: False
# FPS: 2.96
#
# 0: 480x640 12 persons, 198.5ms
# Speed: 4.1ms preprocess, 198.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person at bottom center (592.0, 290.0) - in_road: False, in_zebra: False
# Person at bottom center (23.0, 281.0) - in_road: False, in_zebra: False
# Person at bottom center (580.0, 446.0) - in_road: False, in_zebra: False
# Person at bottom center (538.0, 446.0) - in_road: False, in_zebra: False
# Person at bottom center (456.0, 445.0) - in_road: False, in_zebra: False
# Person at bottom center (490.0, 445.0) - in_road: False, in_zebra: False
# Person at bottom center (324.0, 170.0) - in_road: False, in_zebra: False
# Person at bottom center (578.0, 196.0) - in_road: False, in_zebra: False
# Person at bottom center (7.0, 280.0) - in_road: False, in_zebra: False
# Person at bottom center (582.5, 190.0) - in_road: False, in_zebra: False
# Person at bottom center (309.0, 172.0) - in_road: False, in_zebra: False
# Person at bottom center (575.0, 197.0) - in_road: False, in_zebra: False
#
# 0: 480x640 11 persons, 332.6ms
# Speed: 62.5ms preprocess, 332.6ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
# Person at bottom center (592.5, 289.0) - in_road: False, in_zebra: False
# Person at bottom center (23.0, 281.0) - in_road: False, in_zebra: False
# Person at bottom center (579.5, 447.0) - in_road: False, in_zebra: False
# Person at bottom center (538.0, 446.0) - in_road: False, in_zebra: False
# Person at bottom center (456.0, 445.0) - in_road: False, in_zebra: False
# Person at bottom center (490.0, 445.0) - in_road: False, in_zebra: False
# Person at bottom center (324.0, 170.0) - in_road: False, in_zebra: False
# Person at bottom center (578.0, 193.0) - in_road: False, in_zebra: False
# Person at bottom center (582.0, 188.0) - in_road: False, in_zebra: False
# Person at bottom center (7.0, 280.0) - in_road: False, in_zebra: False
# Person at bottom center (309.5, 172.0) - in_road: False, in_zebra: False
#
# 0: 480x640 11 persons, 248.9ms
# Speed: 3.6ms preprocess, 248.9ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
# Person at bottom center (592.5, 289.0) - in_road: False, in_zebra: False
# Person at bottom center (23.0, 281.0) - in_road: False, in_zebra: False
# Person at bottom center (580.0, 447.0) - in_road: False, in_zebra: False
# Person at bottom center (538.0, 446.0) - in_road: False, in_zebra: False
# Person at bottom center (490.5, 445.0) - in_road: False, in_zebra: False
# Person at bottom center (455.0, 445.0) - in_road: False, in_zebra: False
# Person at bottom center (324.0, 170.0) - in_road: False, in_zebra: False
# Person at bottom center (7.5, 280.0) - in_road: False, in_zebra: False
# Person at bottom center (585.0, 188.0) - in_road: False, in_zebra: False
# Person at bottom center (310.0, 172.0) - in_road: False, in_zebra: False
# Person at bottom center (575.5, 193.0) - in_road: False, in_zebra: False
# FPS: 2.79
#
# 0: 480x640 11 persons, 253.2ms
# Speed: 8.2ms preprocess, 253.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person at bottom center (593.0, 289.0) - in_road: False, in_zebra: False
# Person at bottom center (22.5, 281.0) - in_road: False, in_zebra: False
# Person at bottom center (580.0, 447.0) - in_road: False, in_zebra: False
# Person at bottom center (537.5, 447.0) - in_road: False, in_zebra: False
# Person at bottom center (493.0, 445.0) - in_road: False, in_zebra: False
# Person at bottom center (455.5, 445.0) - in_road: False, in_zebra: False
# Person at bottom center (323.5, 170.0) - in_road: False, in_zebra: False
# Person at bottom center (310.0, 172.0) - in_road: False, in_zebra: False
# Person at bottom center (584.5, 188.0) - in_road: False, in_zebra: False
# Person at bottom center (6.5, 280.0) - in_road: False, in_zebra: False
# Person at bottom center (312.5, 166.0) - in_road: False, in_zebra: False
#
# 0: 480x640 12 persons, 287.8ms
# Speed: 6.9ms preprocess, 287.8ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# Person at bottom center (593.0, 288.0) - in_road: False, in_zebra: False
# Person at bottom center (22.5, 281.0) - in_road: False, in_zebra: False
# Person at bottom center (580.5, 447.0) - in_road: False, in_zebra: False
# Person at bottom center (493.5, 445.0) - in_road: False, in_zebra: False
# Person at bottom center (537.5, 446.0) - in_road: False, in_zebra: False
# Person at bottom center (323.5, 170.0) - in_road: False, in_zebra: False
# Person at bottom center (455.5, 445.0) - in_road: False, in_zebra: False
# Person at bottom center (309.5, 172.0) - in_road: False, in_zebra: False
# Person at bottom center (585.0, 188.0) - in_road: False, in_zebra: False
# Person at bottom center (573.0, 200.0) - in_road: False, in_zebra: False
# Person at bottom center (6.0, 280.0) - in_road: False, in_zebra: False
# Person at bottom center (312.0, 165.0) - in_road: False, in_zebra: False
#
# 0: 480x640 12 persons, 183.9ms
# Speed: 6.0ms preprocess, 183.9ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# Person at bottom center (593.0, 288.0) - in_road: False, in_zebra: False
# Person at bottom center (21.5, 281.0) - in_road: False, in_zebra: False
# Person at bottom center (580.0, 447.0) - in_road: False, in_zebra: False
# Person at bottom center (537.0, 446.0) - in_road: False, in_zebra: False
# Person at bottom center (490.5, 445.0) - in_road: False, in_zebra: False
# Person at bottom center (457.5, 445.0) - in_road: False, in_zebra: False
# Person at bottom center (323.5, 170.0) - in_road: False, in_zebra: False
# Person at bottom center (572.5, 200.0) - in_road: False, in_zebra: False
# Person at bottom center (584.0, 188.0) - in_road: False, in_zebra: False
# Person at bottom center (310.0, 172.0) - in_road: False, in_zebra: False
# Person at bottom center (6.5, 278.0) - in_road: False, in_zebra: False
# Person at bottom center (312.0, 160.0) - in_road: False, in_zebra: False
#
# 0: 480x640 12 persons, 265.6ms
# Speed: 5.0ms preprocess, 265.6ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
# Person at bottom center (593.0, 288.0) - in_road: False, in_zebra: False
# Person at bottom center (22.0, 281.0) - in_road: False, in_zebra: False
# Person at bottom center (580.0, 447.0) - in_road: False, in_zebra: False
# Person at bottom center (537.5, 446.0) - in_road: False, in_zebra: False
# Person at bottom center (493.5, 446.0) - in_road: False, in_zebra: False
# Person at bottom center (458.5, 445.0) - in_road: False, in_zebra: False
# Person at bottom center (323.5, 170.0) - in_road: False, in_zebra: False
# Person at bottom center (584.0, 188.0) - in_road: False, in_zebra: False
# Person at bottom center (572.0, 198.0) - in_road: False, in_zebra: False
# Person at bottom center (310.0, 172.0) - in_road: False, in_zebra: False
# Person at bottom center (6.5, 279.0) - in_road: False, in_zebra: False
# Person at bottom center (312.0, 160.0) - in_road: False, in_zebra: False
# FPS: 3.04
#
# 0: 480x640 12 persons, 185.8ms
# Speed: 7.0ms preprocess, 185.8ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
# Person at bottom center (593.0, 286.0) - in_road: False, in_zebra: False
# Person at bottom center (22.0, 281.0) - in_road: False, in_zebra: False
# Person at bottom center (580.5, 447.0) - in_road: False, in_zebra: False
# Person at bottom center (538.0, 446.0) - in_road: False, in_zebra: False
# Person at bottom center (494.5, 446.0) - in_road: False, in_zebra: False
# Person at bottom center (461.0, 443.0) - in_road: False, in_zebra: False
# Person at bottom center (323.0, 170.0) - in_road: False, in_zebra: False
# Person at bottom center (583.5, 188.0) - in_road: False, in_zebra: False
# Person at bottom center (571.0, 195.0) - in_road: False, in_zebra: False
# Person at bottom center (571.0, 180.0) - in_road: False, in_zebra: False
# Person at bottom center (6.0, 280.0) - in_road: False, in_zebra: False
# Person at bottom center (309.5, 172.0) - in_road: False, in_zebra: False
#
# 0: 480x640 12 persons, 189.8ms
# Speed: 8.3ms preprocess, 189.8ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
# Person at bottom center (21.5, 281.0) - in_road: False, in_zebra: False
# Person at bottom center (593.0, 285.0) - in_road: False, in_zebra: False
# Person at bottom center (580.0, 447.0) - in_road: False, in_zebra: False
# Person at bottom center (538.0, 446.0) - in_road: False, in_zebra: False
# Person at bottom center (494.5, 446.0) - in_road: False, in_zebra: False
# Person at bottom center (461.0, 443.0) - in_road: False, in_zebra: False
# Person at bottom center (323.5, 170.0) - in_road: False, in_zebra: False
# Person at bottom center (583.5, 188.0) - in_road: False, in_zebra: False
# Person at bottom center (571.0, 194.0) - in_road: False, in_zebra: False
# Person at bottom center (570.5, 179.0) - in_road: False, in_zebra: False
# Person at bottom center (6.0, 280.0) - in_road: False, in_zebra: False
# Person at bottom center (309.0, 173.0) - in_road: False, in_zebra: False
#
# 0: 480x640 12 persons, 193.0ms
# Speed: 3.8ms preprocess, 193.0ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
# Person at bottom center (593.0, 281.0) - in_road: False, in_zebra: False
# Person at bottom center (21.0, 281.0) - in_road: False, in_zebra: False
# Person at bottom center (580.0, 447.0) - in_road: False, in_zebra: False
# Person at bottom center (538.0, 446.0) - in_road: False, in_zebra: False
# Person at bottom center (495.5, 447.0) - in_road: False, in_zebra: False
# Person at bottom center (460.5, 444.0) - in_road: False, in_zebra: False
# Person at bottom center (324.0, 170.0) - in_road: False, in_zebra: False
# Person at bottom center (570.0, 199.0) - in_road: False, in_zebra: False
# Person at bottom center (582.5, 188.0) - in_road: False, in_zebra: False
# Person at bottom center (569.5, 185.0) - in_road: False, in_zebra: False
# Person at bottom center (6.0, 280.0) - in_road: False, in_zebra: False
# Person at bottom center (310.0, 173.0) - in_road: False, in_zebra: False
#
# 0: 480x640 11 persons, 198.8ms
# Speed: 5.1ms preprocess, 198.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person at bottom center (21.0, 281.0) - in_road: False, in_zebra: False
# Person at bottom center (593.5, 280.0) - in_road: False, in_zebra: False
# Person at bottom center (580.0, 447.0) - in_road: False, in_zebra: False
# Person at bottom center (538.0, 446.0) - in_road: False, in_zebra: False
# Person at bottom center (495.0, 446.0) - in_road: False, in_zebra: False
# Person at bottom center (460.5, 444.0) - in_road: False, in_zebra: False
# Person at bottom center (324.0, 170.0) - in_road: False, in_zebra: False
# Person at bottom center (570.0, 200.0) - in_road: False, in_zebra: False
# Person at bottom center (582.5, 187.0) - in_road: False, in_zebra: False
# Person at bottom center (7.0, 282.0) - in_road: False, in_zebra: False
# Person at bottom center (310.0, 173.0) - in_road: False, in_zebra: False
# FPS: 3.70
#
# 0: 480x640 11 persons, 186.9ms
# Speed: 4.5ms preprocess, 186.9ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
# Person at bottom center (593.5, 280.0) - in_road: False, in_zebra: False
# Person at bottom center (21.0, 281.0) - in_road: False, in_zebra: False
# Person at bottom center (580.5, 447.0) - in_road: False, in_zebra: False
# Person at bottom center (538.0, 446.0) - in_road: False, in_zebra: False
# Person at bottom center (460.5, 445.0) - in_road: False, in_zebra: False
# Person at bottom center (324.0, 170.0) - in_road: False, in_zebra: False
# Person at bottom center (495.0, 447.0) - in_road: False, in_zebra: False
# Person at bottom center (569.0, 202.0) - in_road: False, in_zebra: False
# Person at bottom center (582.0, 188.0) - in_road: False, in_zebra: False
# Person at bottom center (6.0, 280.0) - in_road: False, in_zebra: False
# Person at bottom center (309.0, 173.0) - in_road: False, in_zebra: False
#
# 0: 480x640 11 persons, 195.8ms
# Speed: 6.1ms preprocess, 195.8ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
# Person at bottom center (594.0, 279.0) - in_road: False, in_zebra: False
# Person at bottom center (21.5, 281.0) - in_road: False, in_zebra: False
# Person at bottom center (538.0, 446.0) - in_road: False, in_zebra: False
# Person at bottom center (581.0, 448.0) - in_road: False, in_zebra: False
# Person at bottom center (460.5, 447.0) - in_road: False, in_zebra: False
# Person at bottom center (569.0, 202.0) - in_road: False, in_zebra: False
# Person at bottom center (324.0, 170.0) - in_road: False, in_zebra: False
# Person at bottom center (493.5, 446.0) - in_road: False, in_zebra: False
# Person at bottom center (582.0, 188.0) - in_road: False, in_zebra: False
# Person at bottom center (7.0, 281.0) - in_road: False, in_zebra: False
# Person at bottom center (309.0, 173.0) - in_road: False, in_zebra: False
#
# 0: 480x640 11 persons, 198.0ms
# Speed: 3.9ms preprocess, 198.0ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# Person at bottom center (594.5, 279.0) - in_road: False, in_zebra: False
# Person at bottom center (21.0, 281.0) - in_road: False, in_zebra: False
# Person at bottom center (538.5, 446.0) - in_road: False, in_zebra: False
# Person at bottom center (581.0, 448.0) - in_road: False, in_zebra: False
# Person at bottom center (568.5, 202.0) - in_road: False, in_zebra: False
# Person at bottom center (460.5, 447.0) - in_road: False, in_zebra: False
# Person at bottom center (324.0, 170.0) - in_road: False, in_zebra: False
# Person at bottom center (493.5, 446.0) - in_road: False, in_zebra: False
# Person at bottom center (7.0, 281.0) - in_road: False, in_zebra: False
# Person at bottom center (581.5, 188.0) - in_road: False, in_zebra: False
# Person at bottom center (309.0, 173.0) - in_road: False, in_zebra: False
#
# 0: 480x640 11 persons, 191.2ms
# Speed: 3.4ms preprocess, 191.2ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
# Person at bottom center (595.0, 279.0) - in_road: False, in_zebra: False
# Person at bottom center (21.0, 281.0) - in_road: False, in_zebra: False
# Person at bottom center (581.5, 448.0) - in_road: False, in_zebra: False
# Person at bottom center (538.5, 446.0) - in_road: False, in_zebra: False
# Person at bottom center (460.5, 447.0) - in_road: False, in_zebra: False
# Person at bottom center (568.5, 197.0) - in_road: False, in_zebra: False
# Person at bottom center (324.0, 171.0) - in_road: False, in_zebra: False
# Person at bottom center (493.5, 447.0) - in_road: False, in_zebra: False
# Person at bottom center (6.5, 280.0) - in_road: False, in_zebra: False
# Person at bottom center (581.5, 186.0) - in_road: False, in_zebra: False
# Person at bottom center (309.0, 173.0) - in_road: False, in_zebra: False
# FPS: 3.70
#
# 0: 480x640 11 persons, 185.1ms
# Speed: 3.8ms preprocess, 185.1ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# Person at bottom center (595.5, 278.0) - in_road: False, in_zebra: False
# Person at bottom center (21.0, 281.0) - in_road: False, in_zebra: False
# Person at bottom center (581.5, 448.0) - in_road: False, in_zebra: False
# Person at bottom center (538.5, 446.0) - in_road: False, in_zebra: False
# Person at bottom center (324.0, 171.0) - in_road: False, in_zebra: False
# Person at bottom center (455.0, 445.0) - in_road: False, in_zebra: False
# Person at bottom center (494.0, 447.0) - in_road: False, in_zebra: False
# Person at bottom center (568.5, 193.0) - in_road: False, in_zebra: False
# Person at bottom center (6.5, 280.0) - in_road: False, in_zebra: False
# Person at bottom center (308.5, 173.0) - in_road: False, in_zebra: False
# Person at bottom center (581.0, 188.0) - in_road: False, in_zebra: False
#
# 0: 480x640 11 persons, 192.1ms
# Speed: 7.1ms preprocess, 192.1ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# Person at bottom center (21.0, 281.0) - in_road: False, in_zebra: False
# Person at bottom center (596.5, 278.0) - in_road: False, in_zebra: False
# Person at bottom center (581.5, 448.0) - in_road: False, in_zebra: False
# Person at bottom center (454.0, 446.0) - in_road: False, in_zebra: False
# Person at bottom center (538.0, 446.0) - in_road: False, in_zebra: False
# Person at bottom center (324.0, 170.0) - in_road: False, in_zebra: False
# Person at bottom center (494.5, 446.0) - in_road: False, in_zebra: False
# Person at bottom center (6.5, 280.0) - in_road: False, in_zebra: False
# Person at bottom center (565.5, 194.0) - in_road: False, in_zebra: False
# Person at bottom center (579.0, 189.0) - in_road: False, in_zebra: False
# Person at bottom center (308.0, 173.0) - in_road: False, in_zebra: False
#
# 0: 480x640 11 persons, 193.1ms
# Speed: 5.2ms preprocess, 193.1ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
# Person at bottom center (21.0, 281.0) - in_road: False, in_zebra: False
# Person at bottom center (597.5, 278.0) - in_road: False, in_zebra: False
# Person at bottom center (581.5, 448.0) - in_road: False, in_zebra: False
# Person at bottom center (539.0, 446.0) - in_road: False, in_zebra: False
# Person at bottom center (324.0, 170.0) - in_road: False, in_zebra: False
# Person at bottom center (453.5, 447.0) - in_road: False, in_zebra: False
# Person at bottom center (491.5, 446.0) - in_road: False, in_zebra: False
# Person at bottom center (565.0, 196.0) - in_road: False, in_zebra: False
# Person at bottom center (6.5, 280.0) - in_road: False, in_zebra: False
# Person at bottom center (579.0, 189.0) - in_road: False, in_zebra: False
# Person at bottom center (308.5, 173.0) - in_road: False, in_zebra: False
#
# 0: 480x640 12 persons, 196.4ms
# Speed: 4.0ms preprocess, 196.4ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
# Person at bottom center (21.0, 281.0) - in_road: False, in_zebra: False
# Person at bottom center (599.0, 277.0) - in_road: False, in_zebra: False
# Person at bottom center (581.0, 448.0) - in_road: False, in_zebra: False
# Person at bottom center (564.5, 201.0) - in_road: False, in_zebra: False
# Person at bottom center (453.0, 447.0) - in_road: False, in_zebra: False
# Person at bottom center (324.0, 170.0) - in_road: False, in_zebra: False
# Person at bottom center (538.0, 446.0) - in_road: False, in_zebra: False
# Person at bottom center (492.0, 446.0) - in_road: False, in_zebra: False
# Person at bottom center (6.5, 280.0) - in_road: False, in_zebra: False
# Person at bottom center (460.5, 446.0) - in_road: False, in_zebra: False
# Person at bottom center (578.0, 190.0) - in_road: False, in_zebra: False
# Person at bottom center (370.5, 479.0) - in_road: False, in_zebra: False
# FPS: 3.72
#
# 0: 480x640 11 persons, 188.7ms
# Speed: 7.2ms preprocess, 188.7ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
# Person at bottom center (21.0, 281.0) - in_road: False, in_zebra: False
# Person at bottom center (599.5, 277.0) - in_road: False, in_zebra: False
# Person at bottom center (580.5, 448.0) - in_road: False, in_zebra: False
# Person at bottom center (564.5, 201.0) - in_road: False, in_zebra: False
# Person at bottom center (453.0, 447.0) - in_road: False, in_zebra: False
# Person at bottom center (324.0, 170.0) - in_road: False, in_zebra: False
# Person at bottom center (494.5, 446.0) - in_road: False, in_zebra: False
# Person at bottom center (6.5, 280.0) - in_road: False, in_zebra: False
# Person at bottom center (539.0, 446.0) - in_road: False, in_zebra: False
# Person at bottom center (460.0, 446.0) - in_road: False, in_zebra: False
# Person at bottom center (577.5, 190.0) - in_road: False, in_zebra: False
#
# 0: 480x640 12 persons, 204.7ms
# Speed: 6.2ms preprocess, 204.7ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# Person at bottom center (20.5, 282.0) - in_road: False, in_zebra: False
# Person at bottom center (600.5, 275.0) - in_road: False, in_zebra: False
# Person at bottom center (581.5, 448.0) - in_road: False, in_zebra: False
# Person at bottom center (323.5, 171.0) - in_road: False, in_zebra: False
# Person at bottom center (454.5, 443.0) - in_road: False, in_zebra: False
# Person at bottom center (490.0, 446.0) - in_road: False, in_zebra: False
# Person at bottom center (6.5, 281.0) - in_road: False, in_zebra: False
# Person at bottom center (538.0, 446.0) - in_road: False, in_zebra: False
# Person at bottom center (563.0, 198.0) - in_road: False, in_zebra: False
# Person at bottom center (576.5, 191.0) - in_road: False, in_zebra: False
# Person at bottom center (307.0, 172.0) - in_road: False, in_zebra: False
# Person at bottom center (300.5, 171.0) - in_road: False, in_zebra: False
#
# 0: 480x640 12 persons, 187.6ms
# Speed: 7.2ms preprocess, 187.6ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
# Person at bottom center (20.5, 282.0) - in_road: False, in_zebra: False
# Person at bottom center (601.0, 275.0) - in_road: False, in_zebra: False
# Person at bottom center (581.0, 448.0) - in_road: False, in_zebra: False
# Person at bottom center (323.5, 171.0) - in_road: False, in_zebra: False
# Person at bottom center (454.5, 443.0) - in_road: False, in_zebra: False
# Person at bottom center (491.0, 446.0) - in_road: False, in_zebra: False
# Person at bottom center (6.5, 281.0) - in_road: False, in_zebra: False
# Person at bottom center (537.5, 445.0) - in_road: False, in_zebra: False
# Person at bottom center (562.5, 198.0) - in_road: False, in_zebra: False
# Person at bottom center (308.0, 173.0) - in_road: False, in_zebra: False
# Person at bottom center (576.0, 191.0) - in_road: False, in_zebra: False
# Person at bottom center (300.5, 171.0) - in_road: False, in_zebra: False
#
# 0: 480x640 16 persons, 321.9ms
# Speed: 4.4ms preprocess, 321.9ms inference, 5.7ms postprocess per image at shape (1, 3, 480, 640)
# Person at bottom center (601.5, 275.0) - in_road: False, in_zebra: False
# Person at bottom center (21.0, 282.0) - in_road: False, in_zebra: False
# Person at bottom center (581.5, 448.0) - in_road: False, in_zebra: False
# Person at bottom center (323.5, 171.0) - in_road: False, in_zebra: False
# Person at bottom center (454.5, 443.0) - in_road: False, in_zebra: False
# Person at bottom center (489.5, 446.0) - in_road: False, in_zebra: False
# Person at bottom center (6.5, 281.0) - in_road: False, in_zebra: False
# Person at bottom center (377.0, 479.0) - in_road: False, in_zebra: False
# Person at bottom center (538.5, 446.0) - in_road: False, in_zebra: False
# Person at bottom center (308.0, 173.0) - in_road: False, in_zebra: False
# Person at bottom center (559.0, 198.0) - in_road: False, in_zebra: False
# Person at bottom center (300.5, 172.0) - in_road: False, in_zebra: False
# Person at bottom center (560.5, 201.0) - in_road: False, in_zebra: False
# Person at bottom center (305.5, 173.0) - in_road: False, in_zebra: False
# Person at bottom center (574.0, 192.0) - in_road: False, in_zebra: False
# Person at bottom center (557.5, 186.0) - in_road: False, in_zebra: False
# FPS: 3.28
#
# 0: 480x640 15 persons, 198.0ms
# Speed: 3.9ms preprocess, 198.0ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# Person at bottom center (601.5, 274.0) - in_road: False, in_zebra: False
# Person at bottom center (21.0, 282.0) - in_road: False, in_zebra: False
# Person at bottom center (581.5, 448.0) - in_road: False, in_zebra: False
# Person at bottom center (323.5, 171.0) - in_road: False, in_zebra: False
# Person at bottom center (454.5, 443.0) - in_road: False, in_zebra: False
# Person at bottom center (489.5, 446.0) - in_road: False, in_zebra: False
# Person at bottom center (6.5, 281.0) - in_road: False, in_zebra: False
# Person at bottom center (378.0, 479.0) - in_road: False, in_zebra: False
# Person at bottom center (538.5, 446.0) - in_road: False, in_zebra: False
# Person at bottom center (574.0, 192.0) - in_road: False, in_zebra: False
# Person at bottom center (557.0, 199.0) - in_road: False, in_zebra: False
# Person at bottom center (308.5, 172.0) - in_road: False, in_zebra: False
# Person at bottom center (559.0, 202.0) - in_road: False, in_zebra: False
# Person at bottom center (300.5, 172.0) - in_road: False, in_zebra: False
# Person at bottom center (305.5, 173.0) - in_road: False, in_zebra: False
#
# 0: 480x640 14 persons, 201.7ms
# Speed: 7.3ms preprocess, 201.7ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
# Person at bottom center (21.0, 282.0) - in_road: False, in_zebra: False
# Person at bottom center (602.0, 274.0) - in_road: False, in_zebra: False
# Person at bottom center (582.0, 448.0) - in_road: False, in_zebra: False
# Person at bottom center (323.5, 171.0) - in_road: False, in_zebra: False
# Person at bottom center (454.0, 443.0) - in_road: False, in_zebra: False
# Person at bottom center (490.0, 446.0) - in_road: False, in_zebra: False
# Person at bottom center (6.5, 281.0) - in_road: False, in_zebra: False
# Person at bottom center (380.5, 479.0) - in_road: False, in_zebra: False
# Person at bottom center (539.0, 446.0) - in_road: False, in_zebra: False
# Person at bottom center (309.0, 172.0) - in_road: False, in_zebra: False
# Person at bottom center (558.0, 202.0) - in_road: False, in_zebra: False
# Person at bottom center (300.5, 172.0) - in_road: False, in_zebra: False
# Person at bottom center (573.0, 192.0) - in_road: False, in_zebra: False
# Person at bottom center (305.5, 173.0) - in_road: False, in_zebra: False
#
# 0: 480x640 14 persons, 190.4ms
# Speed: 8.2ms preprocess, 190.4ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
# Person at bottom center (21.0, 282.0) - in_road: False, in_zebra: False
# Person at bottom center (603.0, 274.0) - in_road: False, in_zebra: False
# Person at bottom center (582.0, 448.0) - in_road: False, in_zebra: False
# Person at bottom center (323.5, 171.0) - in_road: False, in_zebra: False
# Person at bottom center (454.0, 443.0) - in_road: False, in_zebra: False
# Person at bottom center (489.5, 446.0) - in_road: False, in_zebra: False
# Person at bottom center (6.5, 281.0) - in_road: False, in_zebra: False
# Person at bottom center (309.0, 172.0) - in_road: False, in_zebra: False
# Person at bottom center (557.5, 201.0) - in_road: False, in_zebra: False
# Person at bottom center (539.0, 446.0) - in_road: False, in_zebra: False
# Person at bottom center (382.0, 479.0) - in_road: False, in_zebra: False
# Person at bottom center (571.5, 191.0) - in_road: False, in_zebra: False
# Person at bottom center (300.5, 172.0) - in_road: False, in_zebra: False
# Person at bottom center (306.0, 173.0) - in_road: False, in_zebra: False
#
# 0: 480x640 13 persons, 186.6ms
# Speed: 4.4ms preprocess, 186.6ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
# Person at bottom center (21.0, 281.0) - in_road: False, in_zebra: False
# Person at bottom center (603.5, 273.0) - in_road: False, in_zebra: False
# Person at bottom center (583.0, 448.0) - in_road: False, in_zebra: False
# Person at bottom center (323.5, 171.0) - in_road: False, in_zebra: False
# Person at bottom center (452.0, 430.0) - in_road: False, in_zebra: False
# Person at bottom center (491.0, 446.0) - in_road: False, in_zebra: False
# Person at bottom center (6.0, 281.0) - in_road: False, in_zebra: False
# Person at bottom center (309.0, 173.0) - in_road: False, in_zebra: False
# Person at bottom center (384.5, 479.0) - in_road: False, in_zebra: False
# Person at bottom center (570.0, 191.0) - in_road: False, in_zebra: False
# Person at bottom center (537.5, 446.0) - in_road: False, in_zebra: False
# Person at bottom center (556.5, 201.0) - in_road: False, in_zebra: False
# Person at bottom center (301.0, 172.0) - in_road: False, in_zebra: False
# FPS: 3.66
#
# 0: 480x640 13 persons, 198.2ms
# Speed: 5.0ms preprocess, 198.2ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
# Person at bottom center (21.0, 282.0) - in_road: False, in_zebra: False
# Person at bottom center (603.5, 272.0) - in_road: False, in_zebra: False
# Person at bottom center (582.5, 448.0) - in_road: False, in_zebra: False
# Person at bottom center (324.0, 171.0) - in_road: False, in_zebra: False
# Person at bottom center (452.0, 432.0) - in_road: False, in_zebra: False
# Person at bottom center (490.5, 446.0) - in_road: False, in_zebra: False
# Person at bottom center (7.0, 282.0) - in_road: False, in_zebra: False
# Person at bottom center (309.0, 173.0) - in_road: False, in_zebra: False
# Person at bottom center (569.0, 191.0) - in_road: False, in_zebra: False
# Person at bottom center (386.0, 479.0) - in_road: False, in_zebra: False
# Person at bottom center (555.5, 201.0) - in_road: False, in_zebra: False
# Person at bottom center (537.0, 446.0) - in_road: False, in_zebra: False
# Person at bottom center (301.0, 172.0) - in_road: False, in_zebra: False
#
# 0: 480x640 16 persons, 187.2ms
# Speed: 4.1ms preprocess, 187.2ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
# Person at bottom center (21.0, 282.0) - in_road: False, in_zebra: False
# Person at bottom center (603.5, 273.0) - in_road: False, in_zebra: False
# Person at bottom center (582.0, 448.0) - in_road: False, in_zebra: False
# Person at bottom center (389.0, 479.0) - in_road: False, in_zebra: False
# Person at bottom center (324.0, 171.0) - in_road: False, in_zebra: False
# Person at bottom center (489.5, 446.0) - in_road: False, in_zebra: False
# Person at bottom center (453.0, 436.0) - in_road: False, in_zebra: False
# Person at bottom center (6.0, 281.0) - in_road: False, in_zebra: False
# Person at bottom center (308.5, 173.0) - in_road: False, in_zebra: False
# Person at bottom center (537.0, 446.0) - in_road: False, in_zebra: False
# Person at bottom center (554.5, 199.0) - in_road: False, in_zebra: False
# Person at bottom center (568.0, 191.0) - in_road: False, in_zebra: False
# ...
# Person at bottom center (580.5, 448.0) - in_road: False, in_zebra: False
# Person at bottom center (286.5, 192.0) - in_road: False, in_zebra: False
# Person at bottom center (340.5, 169.0) - in_road: False, in_zebra: False
# Person at bottom center (597.0, 156.0) - in_road: False, in_zebra: False
# Person at bottom center (289.0, 193.0) - in_road: False, in_zebra: False
# Person at bottom center (6.5, 280.0) - in_road: False, in_zebra: False
# Person at bottom center (358.0, 160.0) - in_road: False, in_zebra: False
#
# 0: 480x640 10 persons, 224.7ms
# Speed: 9.5ms preprocess, 224.7ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
# Person at bottom center (20.0, 281.0) - in_road: False, in_zebra: False
# Person at bottom center (612.0, 199.0) - in_road: False, in_zebra: False
# Person at bottom center (536.5, 480.0) - in_road: False, in_zebra: False
# Person at bottom center (246.0, 186.0) - in_road: False, in_zebra: False
# Person at bottom center (467.0, 480.0) - in_road: False, in_zebra: False
# Person at bottom center (286.0, 192.0) - in_road: False, in_zebra: False
# Person at bottom center (580.5, 448.0) - in_road: False, in_zebra: False
# Person at bottom center (340.0, 169.0) - in_road: False, in_zebra: False
# Person at bottom center (597.0, 156.0) - in_road: False, in_zebra: False
# Person at bottom center (6.5, 280.0) - in_road: False, in_zebra: False
#
# 0: 480x640 10 persons, 370.7ms
# Speed: 4.1ms preprocess, 370.7ms inference, 4.2ms postprocess per image at shape (1, 3, 480, 640)
# Person at bottom center (20.0, 281.0) - in_road: False, in_zebra: False
# Person at bottom center (613.0, 199.0) - in_road: False, in_zebra: False
# Person at bottom center (536.0, 480.0) - in_road: False, in_zebra: False
# Person at bottom center (246.0, 186.0) - in_road: False, in_zebra: False
# Person at bottom center (467.0, 480.0) - in_road: False, in_zebra: False
# Person at bottom center (287.0, 192.0) - in_road: False, in_zebra: False
# Person at bottom center (580.5, 448.0) - in_road: False, in_zebra: False
# Person at bottom center (340.5, 169.0) - in_road: False, in_zebra: False
# Person at bottom center (597.0, 158.0) - in_road: False, in_zebra: False
# Person at bottom center (6.5, 280.0) - in_road: False, in_zebra: False
# FPS: 2.94
#
# 0: 480x640 10 persons, 237.2ms
# Speed: 9.5ms preprocess, 237.2ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
# Person at bottom center (20.0, 281.0) - in_road: False, in_zebra: False
# Person at bottom center (613.0, 199.0) - in_road: False, in_zebra: False
# Person at bottom center (536.0, 480.0) - in_road: False, in_zebra: False
# Person at bottom center (467.0, 480.0) - in_road: False, in_zebra: False
# Person at bottom center (246.0, 186.0) - in_road: False, in_zebra: False
# Person at bottom center (287.0, 192.0) - in_road: False, in_zebra: False
# Person at bottom center (580.5, 448.0) - in_road: False, in_zebra: False
# Person at bottom center (340.5, 169.0) - in_road: False, in_zebra: False
# Person at bottom center (597.0, 158.0) - in_road: False, in_zebra: False
# Person at bottom center (6.5, 280.0) - in_road: False, in_zebra: False
#
# 0: 480x640 12 persons, 247.3ms
# Speed: 4.1ms preprocess, 247.3ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# Person at bottom center (20.0, 281.0) - in_road: False, in_zebra: False
# Person at bottom center (536.0, 480.0) - in_road: False, in_zebra: False
# Person at bottom center (612.5, 199.0) - in_road: False, in_zebra: False
# Person at bottom center (466.0, 480.0) - in_road: False, in_zebra: False
# Person at bottom center (245.5, 186.0) - in_road: False, in_zebra: False
# Person at bottom center (580.0, 448.0) - in_road: False, in_zebra: False
# Person at bottom center (288.0, 192.0) - in_road: False, in_zebra: False
# Person at bottom center (340.5, 170.0) - in_road: False, in_zebra: False
# Person at bottom center (596.5, 158.0) - in_road: False, in_zebra: False
# Person at bottom center (288.0, 192.0) - in_road: False, in_zebra: False
# Person at bottom center (357.5, 159.0) - in_road: False, in_zebra: False
# Person at bottom center (6.5, 280.0) - in_road: False, in_zebra: False
#
# 0: 480x640 13 persons, 206.2ms
# Speed: 3.9ms preprocess, 206.2ms inference, 4.4ms postprocess per image at shape (1, 3, 480, 640)
# Person at bottom center (20.0, 281.0) - in_road: False, in_zebra: False
# Person at bottom center (535.5, 480.0) - in_road: False, in_zebra: False
# Person at bottom center (245.5, 187.0) - in_road: False, in_zebra: False
# Person at bottom center (612.5, 199.0) - in_road: False, in_zebra: False
# Person at bottom center (580.0, 449.0) - in_road: False, in_zebra: False
# Person at bottom center (467.5, 479.0) - in_road: False, in_zebra: False
# Person at bottom center (340.0, 170.0) - in_road: False, in_zebra: False
# Person at bottom center (288.0, 192.0) - in_road: False, in_zebra: False
# Person at bottom center (596.5, 158.0) - in_road: False, in_zebra: False
# Person at bottom center (289.5, 192.0) - in_road: False, in_zebra: False
# Person at bottom center (7.0, 280.0) - in_road: False, in_zebra: False
# Person at bottom center (357.5, 160.0) - in_road: False, in_zebra: False
# Person at bottom center (326.0, 162.0) - in_road: False, in_zebra: False
#
# 0: 480x640 13 persons, 208.7ms
# Speed: 5.6ms preprocess, 208.7ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
# Person at bottom center (20.0, 281.0) - in_road: False, in_zebra: False
# Person at bottom center (535.5, 480.0) - in_road: False, in_zebra: False
# Person at bottom center (613.0, 199.0) - in_road: False, in_zebra: False
# Person at bottom center (245.0, 187.0) - in_road: False, in_zebra: False
# Person at bottom center (580.0, 448.0) - in_road: False, in_zebra: False
# Person at bottom center (467.0, 479.0) - in_road: False, in_zebra: False
# Person at bottom center (288.0, 192.0) - in_road: False, in_zebra: False
# Person at bottom center (340.0, 170.0) - in_road: False, in_zebra: False
# Person at bottom center (596.5, 158.0) - in_road: False, in_zebra: False
# Person at bottom center (7.0, 280.0) - in_road: False, in_zebra: False
# Person at bottom center (288.0, 191.0) - in_road: False, in_zebra: False
# Person at bottom center (357.5, 160.0) - in_road: False, in_zebra: False
# Person at bottom center (326.0, 162.0) - in_road: False, in_zebra: False
# FPS: 3.21
#
# 0: 480x640 12 persons, 293.3ms
# Speed: 70.2ms preprocess, 293.3ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# Person at bottom center (20.0, 281.0) - in_road: False, in_zebra: False
# Person at bottom center (613.0, 199.0) - in_road: False, in_zebra: False
# Person at bottom center (536.5, 480.0) - in_road: False, in_zebra: False
# Person at bottom center (245.5, 187.0) - in_road: False, in_zebra: False
# Person at bottom center (580.0, 448.0) - in_road: False, in_zebra: False
# Person at bottom center (288.5, 191.0) - in_road: False, in_zebra: False
# Person at bottom center (466.0, 479.0) - in_road: False, in_zebra: False
# Person at bottom center (340.0, 169.0) - in_road: False, in_zebra: False
# Person at bottom center (596.0, 158.0) - in_road: False, in_zebra: False
# Person at bottom center (7.0, 280.0) - in_road: False, in_zebra: False
# Person at bottom center (357.5, 160.0) - in_road: False, in_zebra: False
# Person at bottom center (325.5, 162.0) - in_road: False, in_zebra: False
#
# 0: 480x640 12 persons, 306.5ms
# Speed: 14.2ms preprocess, 306.5ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
# Person at bottom center (20.0, 281.0) - in_road: False, in_zebra: False
# Person at bottom center (613.0, 199.0) - in_road: False, in_zebra: False
# Person at bottom center (536.5, 480.0) - in_road: False, in_zebra: False
# Person at bottom center (580.0, 448.0) - in_road: False, in_zebra: False
# Person at bottom center (245.5, 187.0) - in_road: False, in_zebra: False
# Person at bottom center (288.5, 190.0) - in_road: False, in_zebra: False
# Person at bottom center (466.0, 479.0) - in_road: False, in_zebra: False
# Person at bottom center (340.0, 170.0) - in_road: False, in_zebra: False
# Person at bottom center (596.5, 158.0) - in_road: False, in_zebra: False
# Person at bottom center (7.0, 280.0) - in_road: False, in_zebra: False
# Person at bottom center (357.5, 160.0) - in_road: False, in_zebra: False
# Person at bottom center (325.5, 162.0) - in_road: False, in_zebra: False
#
# 0: 480x640 12 persons, 227.3ms
# Speed: 6.6ms preprocess, 227.3ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
# Person at bottom center (20.0, 281.0) - in_road: False, in_zebra: False
# Person at bottom center (613.0, 199.0) - in_road: False, in_zebra: False
# Person at bottom center (536.5, 480.0) - in_road: False, in_zebra: False
# Person at bottom center (580.0, 448.0) - in_road: False, in_zebra: False
# Person at bottom center (245.5, 187.0) - in_road: False, in_zebra: False
# Person at bottom center (466.0, 479.0) - in_road: False, in_zebra: False
# Person at bottom center (289.5, 191.0) - in_road: False, in_zebra: False
# Person at bottom center (340.0, 170.0) - in_road: False, in_zebra: False
# Person at bottom center (596.0, 158.0) - in_road: False, in_zebra: False
# Person at bottom center (357.5, 160.0) - in_road: False, in_zebra: False
# Person at bottom center (7.0, 280.0) - in_road: False, in_zebra: False
# Person at bottom center (325.5, 162.0) - in_road: False, in_zebra: False
# FPS: 2.57
#
# 0: 480x640 12 persons, 238.3ms
# Speed: 9.2ms preprocess, 238.3ms inference, 5.5ms postprocess per image at shape (1, 3, 480, 640)
# Person at bottom center (20.5, 281.0) - in_road: False, in_zebra: False
# Person at bottom center (612.5, 199.0) - in_road: False, in_zebra: False
# Person at bottom center (536.0, 480.0) - in_road: False, in_zebra: False
# Person at bottom center (290.0, 191.0) - in_road: False, in_zebra: False
# Person at bottom center (580.5, 449.0) - in_road: False, in_zebra: False
# Person at bottom center (466.0, 479.0) - in_road: False, in_zebra: False
# Person at bottom center (245.5, 187.0) - in_road: False, in_zebra: False
# Person at bottom center (340.5, 170.0) - in_road: False, in_zebra: False
# Person at bottom center (595.5, 159.0) - in_road: False, in_zebra: False
# Person at bottom center (7.0, 280.0) - in_road: False, in_zebra: False
# Person at bottom center (358.0, 159.0) - in_road: False, in_zebra: False
# Person at bottom center (325.5, 162.0) - in_road: False, in_zebra: False
#
# 0: 480x640 12 persons, 255.8ms
# Speed: 9.3ms preprocess, 255.8ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
# Person at bottom center (20.5, 281.0) - in_road: False, in_zebra: False
# Person at bottom center (613.0, 199.0) - in_road: False, in_zebra: False
# Person at bottom center (536.5, 480.0) - in_road: False, in_zebra: False
# Person at bottom center (290.0, 191.0) - in_road: False, in_zebra: False
# Person at bottom center (466.0, 479.0) - in_road: False, in_zebra: False
# Person at bottom center (580.0, 449.0) - in_road: False, in_zebra: False
# Person at bottom center (245.5, 187.0) - in_road: False, in_zebra: False
# Person at bottom center (340.0, 170.0) - in_road: False, in_zebra: False
# Person at bottom center (595.5, 158.0) - in_road: False, in_zebra: False
# Person at bottom center (7.0, 280.0) - in_road: False, in_zebra: False
# Person at bottom center (326.0, 162.0) - in_road: False, in_zebra: False
# Person at bottom center (358.5, 159.0) - in_road: False, in_zebra: False
#
# 0: 480x640 11 persons, 329.4ms
# Speed: 115.6ms preprocess, 329.4ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
# Person at bottom center (20.5, 281.0) - in_road: False, in_zebra: False
# Person at bottom center (613.0, 199.0) - in_road: False, in_zebra: False
# Person at bottom center (536.0, 480.0) - in_road: False, in_zebra: False
# Person at bottom center (290.0, 192.0) - in_road: False, in_zebra: False
# Person at bottom center (580.0, 449.0) - in_road: False, in_zebra: False
# Person at bottom center (466.5, 479.0) - in_road: False, in_zebra: False
# Person at bottom center (245.5, 187.0) - in_road: False, in_zebra: False
# Person at bottom center (340.0, 170.0) - in_road: False, in_zebra: False
# Person at bottom center (7.0, 281.0) - in_road: False, in_zebra: False
# Person at bottom center (326.0, 162.0) - in_road: False, in_zebra: False
# Person at bottom center (595.0, 158.0) - in_road: False, in_zebra: False
# FPS: 2.50
#
# 0: 480x640 11 persons, 200.6ms
# Speed: 4.2ms preprocess, 200.6ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
# Person at bottom center (20.5, 281.0) - in_road: False, in_zebra: False
# Person at bottom center (613.0, 199.0) - in_road: False, in_zebra: False
# Person at bottom center (536.0, 480.0) - in_road: False, in_zebra: False
# Person at bottom center (290.5, 192.0) - in_road: False, in_zebra: False
# Person at bottom center (580.0, 449.0) - in_road: False, in_zebra: False
# Person at bottom center (466.5, 479.0) - in_road: False, in_zebra: False
# Person at bottom center (245.5, 187.0) - in_road: False, in_zebra: False
# Person at bottom center (340.0, 169.0) - in_road: False, in_zebra: False
# Person at bottom center (7.0, 281.0) - in_road: False, in_zebra: False
# Person at bottom center (326.0, 162.0) - in_road: False, in_zebra: False
# Person at bottom center (595.0, 157.0) - in_road: False, in_zebra: False
#
# 0: 480x640 12 persons, 256.8ms
# Speed: 4.3ms preprocess, 256.8ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
# Person at bottom center (20.5, 281.0) - in_road: False, in_zebra: False
# Person at bottom center (612.5, 199.0) - in_road: False, in_zebra: False
# Person at bottom center (536.0, 480.0) - in_road: False, in_zebra: False
# Person at bottom center (340.0, 170.0) - in_road: False, in_zebra: False
# Person at bottom center (245.5, 187.0) - in_road: False, in_zebra: False
# Person at bottom center (466.0, 479.0) - in_road: False, in_zebra: False
# Person at bottom center (580.0, 448.0) - in_road: False, in_zebra: False
# Person at bottom center (291.0, 192.0) - in_road: False, in_zebra: False
# Person at bottom center (295.0, 192.0) - in_road: False, in_zebra: False
# Person at bottom center (7.0, 281.0) - in_road: False, in_zebra: False
# Person at bottom center (326.0, 162.0) - in_road: False, in_zebra: False
# Person at bottom center (358.5, 159.0) - in_road: False, in_zebra: False
#
# 0: 480x640 10 persons, 230.5ms
# Speed: 5.2ms preprocess, 230.5ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
# Person at bottom center (20.5, 281.0) - in_road: False, in_zebra: False
# Person at bottom center (612.5, 199.0) - in_road: False, in_zebra: False
# Person at bottom center (536.0, 480.0) - in_road: False, in_zebra: False
# Person at bottom center (340.0, 170.0) - in_road: False, in_zebra: False
# Person at bottom center (245.5, 187.0) - in_road: False, in_zebra: False
# Person at bottom center (580.5, 448.0) - in_road: False, in_zebra: False
# Person at bottom center (291.0, 192.0) - in_road: False, in_zebra: False
# Person at bottom center (465.5, 479.0) - in_road: False, in_zebra: False
# Person at bottom center (7.0, 281.0) - in_road: False, in_zebra: False
# Person at bottom center (293.0, 192.0) - in_road: False, in_zebra: False
#
# 0: 480x640 11 persons, 426.7ms
# Speed: 3.9ms preprocess, 426.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# Person at bottom center (20.5, 281.0) - in_road: False, in_zebra: False
# Person at bottom center (612.5, 199.0) - in_road: False, in_zebra: False
# Person at bottom center (535.5, 480.0) - in_road: False, in_zebra: False
# Person at bottom center (245.5, 186.0) - in_road: False, in_zebra: False
# Person at bottom center (291.0, 192.0) - in_road: False, in_zebra: False
# Person at bottom center (340.5, 170.0) - in_road: False, in_zebra: False
# Person at bottom center (465.5, 479.0) - in_road: False, in_zebra: False
# Person at bottom center (580.5, 448.0) - in_road: False, in_zebra: False
# Person at bottom center (7.0, 281.0) - in_road: False, in_zebra: False
# Person at bottom center (325.5, 162.0) - in_road: False, in_zebra: False
# Person at bottom center (594.5, 159.0) - in_road: False, in_zebra: False
# FPS: 2.75
# CCTV Detection System stopped
